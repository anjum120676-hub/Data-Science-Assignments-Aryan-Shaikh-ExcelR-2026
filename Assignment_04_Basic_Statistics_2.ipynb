# %% [markdown]
# BASIC STATISTICS-2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
patients = pd.read_csv("../csv_files/Patient_Data.csv")

# show first rows
print(patients.head())

# dataset summary
patients.info()
# Out:
#    PatientID     Name   Department     Doctor  BillAmount  ReceptionistID  \
# 0        101    Alice   Cardiology  Dr. Smith      5000.0               1
# 1        102      Bob    Neurology   Dr. John         NaN               2
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0               1
# 3        104    David   Cardiology  Dr. Smith      6200.0               3
# 4        105      Eva  Dermatology   Dr. Rose         NaN               2
#
#         CheckInTime
# 0  2023-01-10 09:00
# 1  2023-01-11 10:30
# 2  2023-01-12 11:00
# 3  2023-01-13 12:00
# 4  2023-01-14 08:45
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PatientID       6 non-null      int64
#  1   Name            6 non-null      object
#  2   Department      6 non-null      object
#  3   Doctor          6 non-null      object
# ...

# %%
billing_related = patients[['PatientID','Department','Doctor','BillAmount']]

print(billing_related)
# Out:
#    PatientID   Department     Doctor  BillAmount
# 0        101   Cardiology  Dr. Smith      5000.0
# 1        102    Neurology   Dr. John         NaN
# 2        103  Orthopedics    Dr. Lee      7500.0
# 3        104   Cardiology  Dr. Smith      6200.0
# 4        105  Dermatology   Dr. Rose         NaN
# 5        101   Cardiology  Dr. Smith      5000.0

# %%
patients_clean = patients.drop(columns=['ReceptionistID','CheckInTime'])

print(patients_clean.head())
# Out:
#    PatientID     Name   Department     Doctor  BillAmount
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John         NaN
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose         NaN

# %%
patients_clean = patients_clean.drop_duplicates(subset='PatientID')

print("After Removing Duplicates")
print(patients_clean)
# Out:
# After Removing Duplicates
#    PatientID     Name   Department     Doctor  BillAmount
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John         NaN
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose         NaN

# %%
mean_bill = patients_clean['BillAmount'].astype(float).mean()

patients_clean['BillAmount'] = patients_clean['BillAmount'].fillna(mean_bill)

print(patients_clean)
# Out:
#    PatientID     Name   Department     Doctor   BillAmount
# 0        101    Alice   Cardiology  Dr. Smith  5000.000000
# 1        102      Bob    Neurology   Dr. John  6233.333333
# 2        103  Charlie  Orthopedics    Dr. Lee  7500.000000
# 3        104    David   Cardiology  Dr. Smith  6200.000000
# 4        105      Eva  Dermatology   Dr. Rose  6233.333333

# %%
dept_bill = patients_clean.groupby('Department')['BillAmount'].sum()

print("Total Bill Amount per Department")
print(dept_bill)
# Out:
# Total Bill Amount per Department
# Department
# Cardiology     11200.000000
# Dermatology     6233.333333
# Neurology       6233.333333
# Orthopedics     7500.000000
# Name: BillAmount, dtype: float64

# %%
billing = pd.read_csv("../csv_files/Billing_Data.csv")

print(billing.head())
# Out:
#    PatientID  InsuranceCovered  FinalAmount
# 0        101              2000         3000
# 1        102              1500         3500
# 2        103              2500         5000
# 3        104              3000         3200
# 4        105              1000         4000

# %%
merged_data = pd.merge(patients_clean, billing, on='PatientID')

print("Merged Dataset")
print(merged_data)
# Out:
# Merged Dataset
#    PatientID     Name   Department     Doctor   BillAmount  InsuranceCovered  \
# 0        101    Alice   Cardiology  Dr. Smith  5000.000000              2000
# 1        102      Bob    Neurology   Dr. John  6233.333333              1500
# 2        103  Charlie  Orthopedics    Dr. Lee  7500.000000              2500
# 3        104    David   Cardiology  Dr. Smith  6200.000000              3000
# 4        105      Eva  Dermatology   Dr. Rose  6233.333333              1000
#
#    FinalAmount
# 0         3000
# 1         3500
# 2         5000
# 3         3200
# 4         4000

# %%
new_patients = pd.DataFrame({
    'PatientID':[106,107],
    'Name':['Frank','Grace'],
    'Department':['Neurology','Cardiology'],
    'Doctor':['Dr. John','Dr. Smith'],
    'BillAmount':[6800,7200]
})

combined_patients = pd.concat([patients_clean, new_patients], axis=0)

print(combined_patients)
# Out:
#    PatientID     Name   Department     Doctor   BillAmount
# 0        101    Alice   Cardiology  Dr. Smith  5000.000000
# 1        102      Bob    Neurology   Dr. John  6233.333333
# 2        103  Charlie  Orthopedics    Dr. Lee  7500.000000
# 3        104    David   Cardiology  Dr. Smith  6200.000000
# 4        105      Eva  Dermatology   Dr. Rose  6233.333333
# 0        106    Frank    Neurology   Dr. John  6800.000000
# 1        107    Grace   Cardiology  Dr. Smith  7200.000000

# %%
extra_billing = pd.DataFrame({
    'InsuranceCovered':[2000,1500,2500,3000,1000],
    'FinalAmount':[3000,3500,5000,3200,4000]
})

final_dataset = pd.concat([patients_clean.reset_index(drop=True),
                           extra_billing], axis=1)

print(final_dataset)
# Out:
#    PatientID     Name   Department     Doctor   BillAmount  InsuranceCovered  \
# 0        101    Alice   Cardiology  Dr. Smith  5000.000000              2000
# 1        102      Bob    Neurology   Dr. John  6233.333333              1500
# 2        103  Charlie  Orthopedics    Dr. Lee  7500.000000              2500
# 3        104    David   Cardiology  Dr. Smith  6200.000000              3000
# 4        105      Eva  Dermatology   Dr. Rose  6233.333333              1000
#
#    FinalAmount
# 0         3000
# 1         3500
# 2         5000
# 3         3200
# 4         4000

# %%
final_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PatientID         5 non-null      int64
#  1   Name              5 non-null      object
#  2   Department        5 non-null      object
#  3   Doctor            5 non-null      object
#  4   BillAmount        5 non-null      float64
#  5   InsuranceCovered  5 non-null      int64
#  6   FinalAmount       5 non-null      int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 412.0+ bytes
